# %%
# Notebook: Feature Engineering - zip - 1
# Author: Thomas Purk
# Date: 2025-03-21
# Reference: https://www.kaggle.com/datasets/mchirico/montcoalert

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/emergency-911-calls-mcpa/911.csv

# %% [markdown]
# # zip - Data Exploration

# %%
# Notebook Step up steps

import warnings
warnings.filterwarnings('ignore')

df_in_path = '/kaggle/input/emergency-911-calls-mcpa/911.csv'
df_out_path = '/kaggle/working/911.csv'

# Load the data 
df_911 = pd.read_csv(df_in_path)

def report_null_empty(df, feature):
    ''' Prints the count and percent of total of null or empty feature (column) values.
    
    Parameters: 
        df (dataframe): A Pandas dataframe which contains the fature.
        feature (string): The name of the feature in the dataframe to report on.
    '''
    null_count = df[feature].isnull().sum()
    empty_count = (df[feature] == "").sum()
    false_count = (df[feature] == False).sum()
    nan_count = (df[feature].isna()).sum()
    print('')
    print(f'{feature}: Null / Empty Report')
    print(f'\tRow count: {len(df)}')
    print(f'\tNull count: {null_count}')
    print(f'\tNull percent: {round(null_count / len(df) * 100,6)}%')
    print(f'\tEmpty count: {empty_count}')
    print(f'\tEmpty precent: {round(empty_count / len(df) * 100,6)}%')
    print(f'\tFalse count: {false_count}')
    print(f'\tFalse precent: {round(false_count / len(df) * 100,6)}%')
    print(f'\tNAN count: {nan_count}')
    print(f'\tNAN precent: {round(nan_count / len(df) * 100,6)}%')

def get_one_offs(df, feature):

    # Count occurrences of each value in feature
    value_counts = df[feature].value_counts()
    
    # Identify values that appear only once
    unique_values = value_counts[value_counts == 1].index
    
    # Filter the DataFrame to include only rows with unique values in feature
    return df[df[feature].isin(unique_values)]

# %%
# Display basic information
display(df_911.info())
display(df_911.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649696 entries, 0 to 649695
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   zip           574587 non-null  float64
#  1   twp           649696 non-null  object
#  2   e             649696 non-null  int64
#  3   twp_type      649696 non-null  object
#  4   road_type     649696 non-null  object
#  5   serivce_type  649696 non-null  object
#  6   serivce_desc  649696 non-null  object
#  7   month         649696 non-null  int64
#  8   day_of_week   649696 non-null  int64
#  9   day_night     649696 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 49.6+ MB
# None
#        zip                        twp  e  twp_type road_type serivce_type  \
# 0  19525.0       NEW HANOVER TOWNSHIP  1  township     minor          EMS
# 1  19446.0          HATFIELD TOWNSHIP  1  township     minor          EMS
# 2  19401.0         NORRISTOWN BOROUGH  1   borough    medium         Fire
# 3  19401.0         NORRISTOWN BOROUGH  1   borough     minor          EMS
# 4      NaN  LOWER POTTSGROVE TOWNSHIP  1  township     minor          EMS
#
#          serivce_desc  month  day_of_week day_night
# 0   BACK PAINS/INJURY     12            3       day
# 1  DIABETIC EMERGENCY     12            3       day
# 2       GAS-ODOR/LEAK     12            3       day
# 3   CARDIAC EMERGENCY     12            3       day
# 4           DIZZINESS     12            3       day

# %%
# Inspect the zip feature
print("### month ###")
display(df_911['zip'].describe())
report_null_empty(df_911,'zip')
display(get_one_offs(df_911,'zip'))
# Out:
# ### month ###
# count    574587.000000
# mean      19235.567550
# std         296.516027
# min        1104.000000
# 25%       19038.000000
# 50%       19401.000000
# 75%       19446.000000
# max       77316.000000
# Name: zip, dtype: float64
# zip: Null / Empty Report
# 	Row count: 649696
# 	Null count: 75109
# 	Null percent: 11.560638%
# 	Empty count: 0
# 	Empty precent: 0.0%
# 	False count: 0
# 	False precent: 0.0%
# 	NAN count: 75109
# 	NAN precent: 11.560638%
#             zip                        twp  e  twp_type road_type  \
# 24920   36107.0        MONTGOMERY TOWNSHIP  1  township     minor
# 65246   77316.0        MONTGOMERY TOWNSHIP  1  township     minor
# 152194  17555.0       NEW HANOVER TOWNSHIP  1  township     minor
# 234049  19018.0      LOWER MERION TOWNSHIP  1  township     minor
# 269448  18051.0          HATFIELD TOWNSHIP  1  township     minor
# 278019  18049.0      LOWER MERION TOWNSHIP  1  township     minor
# 292943  19144.0          HATFIELD TOWNSHIP  1  township     minor
# 298726  19607.0          WHITPAIN TOWNSHIP  1  township     minor
# 299274  19450.0            TELFORD BOROUGH  1   borough     minor
# 304303  17506.0             AMBLER BOROUGH  1   borough     minor
# 314846   7203.0      UPPER DUBLIN TOWNSHIP  1  township    medium
# 318945   8033.0      LOWER MERION TOWNSHIP  1  township     major
# 319562  19104.0         FRANCONIA TOWNSHIP  1  township     minor
# 350496   8065.0       NEW HANOVER TOWNSHIP  1  township     minor
# 359351   3366.0             TRAPPE BOROUGH  1   borough     minor
# 364769  19140.0         GREEN LANE BOROUGH  1   borough     minor
# 381902  18040.0          POTTSTOWN BOROUGH  1   borough     minor
# 387941  18080.0          WHITPAIN TOWNSHIP  1  township     major
# 392621  17901.0      UPPER MERION TOWNSHIP  1  township    medium
# 403648  19134.0           NARBERTH BOROUGH  1   borough     minor
# 405968  19135.0          ROCKLEDGE BOROUGH  1   borough     minor
# 414541   8502.0      LOWER MERION TOWNSHIP  1  township     major
# 414718  19122.0      LOWER MERION TOWNSHIP  1  township     minor
# 419351  19610.0  LOWER PROVIDENCE TOWNSHIP  1  township     minor
# 422421  18902.0           RED HILL BOROUGH  1   borough     minor
# 427014  19063.0  UPPER PROVIDENCE TOWNSHIP  1  township     minor
# 433201  17810.0      LOWER MERION TOWNSHIP  1  township     minor
# 440653   8077.0           HORSHAM TOWNSHIP  1  township     minor
# 460486  18951.0     UPPER HANOVER TOWNSHIP  1  township     minor
# 479053  19456.0  UPPER PROVIDENCE TOWNSHIP  1  township     minor
# 479435  17507.0    UPPER MORELAND TOWNSHIP  1  township     major
# 480026   1104.0       SPRINGFIELD TOWNSHIP  1  township     minor
# 489311  18042.0  LOWER PROVIDENCE TOWNSHIP  1  township     minor
# 526595  19301.0         PERKIOMEN TOWNSHIP  1  township    medium
# 545443  15090.0     UPPER HANOVER TOWNSHIP  1  township     minor
# 578200  19445.0     UPPER GWYNEDD TOWNSHIP  1  township     minor
# 585465  19425.0      UPPER DUBLIN TOWNSHIP  1  township     minor
# 622935   7081.0       SPRINGFIELD TOWNSHIP  1  township     minor
# 629106   7726.0           HORSHAM TOWNSHIP  1  township     minor
# 629198  17566.0          PLYMOUTH TOWNSHIP  1  township     minor
# 636052  19103.0        WHITEMARSH TOWNSHIP  1  township     minor
# 644737  19312.0      UPPER MERION TOWNSHIP  1  township     minor
#
#        serivce_type               serivce_desc  month  day_of_week day_night
# 24920       Traffic           DISABLED VEHICLE      2            4       day
# 65246           EMS          CARDIAC EMERGENCY      6            3       day
# 152194      Traffic           DISABLED VEHICLE      1            5       day
# 234049      Traffic           ROAD OBSTRUCTION      8            2     night
# 269448      Traffic           DISABLED VEHICLE     11            4       day
# 278019      Traffic           VEHICLE ACCIDENT     12            4       day
# 292943         Fire              BUILDING FIRE      1            4       day
# 298726      Traffic           DISABLED VEHICLE      2            6       day
# 299274      Traffic           VEHICLE ACCIDENT      2            0       day
# 304303      Traffic           ROAD OBSTRUCTION      2            6       day
# 314846      Traffic           DISABLED VEHICLE      3            4       day
# 318945      Traffic           DISABLED VEHICLE      3            2       day
# 319562      Traffic           DISABLED VEHICLE      3            3       day
# 350496      Traffic           DISABLED VEHICLE      6            1     night
# 359351      Traffic           ROAD OBSTRUCTION      7            1       day
# 364769      Traffic  HAZARDOUS ROAD CONDITIONS      7            1       day
# 381902          EMS                HEAD INJURY      8            3       day
# 387941      Traffic           DISABLED VEHICLE      9            4       day
# 392621      Traffic           VEHICLE ACCIDENT      9            2       day
# 403648         Fire              GAS-ODOR/LEAK     10            1       day
# 405968      Traffic           DISABLED VEHICLE     10            0       day
# 414541      Traffic           DISABLED VEHICLE     11            3       day
# 414718      Traffic           DISABLED VEHICLE     11            3       day
# 419351      Traffic           DISABLED VEHICLE     11            0     night
# 422421      Traffic  HAZARDOUS ROAD CONDITIONS     12            1       day
# 427014      Traffic           VEHICLE ACCIDENT     12            6       day
# 433201      Traffic           DISABLED VEHICLE      1            2     night
# 440653      Traffic           DISABLED VEHICLE      1            0       day
# 460486      Traffic           DISABLED VEHICLE      3            6       day
# 479053          EMS  UNKNOWN MEDICAL EMERGENCY      4            6       day
# 479435      Traffic           ROAD OBSTRUCTION      4            0       day
# 480026      Traffic           DISABLED VEHICLE      5            2     night
# 489311      Traffic           DISABLED VEHICLE      5            4       day
# 526595          EMS      RESPIRATORY EMERGENCY      8            5     night
# 545443          EMS            NAUSEA/VOMITING     10            4       day
# 578200      Traffic           DISABLED VEHICLE     12            0       day
# 585465      Traffic           DISABLED VEHICLE      1            5       day
# 622935      Traffic           VEHICLE ACCIDENT      5            3     night
# 629106      Traffic           ROAD OBSTRUCTION      6            2       day
# 629198      Traffic           ROAD OBSTRUCTION      6            2       day
# 636052          EMS        UNCONSCIOUS SUBJECT      6            4       day
# 644737      Traffic           VEHICLE ACCIDENT      7            2     night

# %%
print(df_911['zip'].nunique())
# Out:
# zip
# 19401.0    45575
# 19464.0    43851
# 19403.0    34866
# 19446.0    32253
# 19406.0    22441
#            ...
# 17901.0        1
# 19134.0        1
# 19135.0        1
# 8502.0         1
# 19312.0        1
# Name: count, Length: 164, dtype: int64
#
# 164

# %% [markdown]
# **NOTES**
# - 12% null values
# - 164 unique values
# - twp is also a geographic identifier like zipcode, but twp is 0% null
# - zip has greater geographic resolution compared to twp, but may not be as strong of a proxy for as twp values for other factors such population density and demographics.
# - Also zip codes could cross county political boundaries
# - Decision is to drop zip in favor of twp as a geographic identifier.

# %%
df_911.drop('zip', axis=1, inplace=True)

# %%
# Update the file
# After Updating
# 1. Manually Download locally
# 2. Manually Updload to a new version of the Kaggle Dataset


# Check if file exists
if os.path.exists(df_out_path):
    os.remove(df_out_path)
    print(f"File '{df_out_path}' has been deleted.")
else:
    print(f"The file '{df_out_path}' does not exist.")

df_911.to_csv(df_out_path, index=False)
# Out:
# The file '/kaggle/working/911.csv' does not exist.
